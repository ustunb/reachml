# %%
#### set directories ####
results_filename <- "../results/audit_stats.csv"

#### load packages ####
packages = c('reticulate', 'tidyverse', 'stringr', 'kableExtra')
for (pkg in packages) {
    library(pkg, character.only = TRUE, warn.conflicts = FALSE, quietly = TRUE, verbose = FALSE)
}
options(dplyr.width = Inf, dplyr.print_max = 1e9)
options(stringsAsFactors = FALSE)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching core tidyverse packages ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
#### script parameters ####
all_data_names = c("fico", "givemecredit", "german")
all_actionset_names = c("simple_1D", "complex_1D", "complex_nD")
all_method_names = c("reach", "ar", "dice")
all_model_types = c("logreg", "xgb", "rf")

#### embellishments ####

EMPTY_TEX_STRING = "---"

ACTIONSET_TITLES = c(
    'complex_nD' = 'Actual',
    'complex_1D' = 'Separable',
    'simple_1D' = 'Simple'
)

METHOD_TITLES = c(
    'reach' = '\\reach{}',
    'ar' = '\\ar{}',
    'dice' = '\\dice{}'
)

MODEL_TYPE_TITLES = c(
    'logreg' = '\\LR{}',
    'rf' = '\\RF{}',
    'xgb' = '\\XGB{}'
)

DATASET_TITLES = c(
    'fico' = '\\ficoinfo{}',
    'givemecredit' = '\\givemecredit{}',
    'german' = '\\germaninfo{}'
)

METRIC_TITLES = c(
    'certifies_infeasibility_cnt' = 'Certifies no recourse',
    'abstains_cnt' = 'Abstains/inconclusive',
    'finds_action_cnt' = 'Finds action',
    'finds_good_action_cnt' = 'Finds valid action',
    'loophole_cnt' = 'Loophole',
    'finds_no_action_cnt' = 'Finds no action',
    'blindspot_cnt' = 'Blindspot'
)

# select metrics for the cells here
# change order of entries to change order in cell
cell_metric_names = c(
    'certifies_infeasibility_cnt',
    'abstains_cnt',
    'finds_action_cnt',
    'loophole_cnt',
    'finds_no_action_cnt',
    'blindspot_cnt'
)

# %%
# #### load data ####
# filter raw results to the datasets and actionsets that you care about
raw_df = read.csv(results_filename) %>%
    filter(data_name %in% all_data_names,
           actionset_name %in% all_actionset_names)
    # basic changes in stat names
    # mutate(stat_name = str_replace(stat_name, "recourse_true_", "recourse_"))

# raw_df = bind_rows(
#     raw_df %>% filter(!grepl("recourse_", stat_name)),
#     raw_df %>% filter(grepl("recourse_", stat_name)) %>% mutate(stat_name = str_replace(stat_name, "_cnt", paste0("_", label_type, "_cnt")))
# )

tmp_df = raw_df %>%
    filter(stat_name == "n", label_type %in% c("pos","neg"), prediction_type %in% c("pos","neg")) %>%
    mutate(n = stat_value) %>%
    select(-starts_with("stat_"), -method_name) %>%
    group_by(data_name, actionset_name, model_type, label_type, prediction_type) %>%
    slice(1) %>%
    ungroup()

samples_df = bind_rows(
    tmp_df,
    # tmp_df %>% group_by(data_name, actionset_name, model_type, label_type) %>% tally(wt = n) %>% mutate(prediction_type = "all"),
    # tmp_df %>% group_by(data_name, actionset_name, model_type, prediction_type) %>% tally(wt = n) %>% mutate(label_type = "all"),
)

samples_df
# Out:
#     label_type prediction_type data_name    actionset_name model_type n
# 1   neg        neg             fico         complex_1D     logreg     2347
# 2   neg        pos             fico         complex_1D     logreg      769
# 3   pos        neg             fico         complex_1D     logreg      933
# 4   pos        pos             fico         complex_1D     logreg     1793
# 5   neg        neg             fico         complex_1D     rf         2553
# 6   neg        pos             fico         complex_1D     rf          563
# 7   pos        neg             fico         complex_1D     rf          855
# 8   pos        pos             fico         complex_1D     rf         1871
# 9   neg        neg             fico         complex_1D     xgb        2355
# 10  neg        pos             fico         complex_1D     xgb         761
# 11  pos        neg             fico         complex_1D     xgb         934
# 12  pos        pos             fico         complex_1D     xgb        1792
# 13  neg        neg             fico         complex_nD     logreg     2347
# 14  neg        pos             fico         complex_nD     logreg      769
# 15  pos        neg             fico         complex_nD     logreg      933
# 16  pos        pos             fico         complex_nD     logreg     1793
# 17  neg        neg             fico         complex_nD     rf         2553
# 18  neg        pos             fico         complex_nD     rf          563
# 19  pos        neg             fico         complex_nD     rf          855
# 20  pos        pos             fico         complex_nD     rf         1871
# 21  neg        neg             fico         complex_nD     xgb        2355
# 22  neg        pos             fico         complex_nD     xgb         761
# 23  pos        neg             fico         complex_nD     xgb         934
# 24  pos        pos             fico         complex_nD     xgb        1792
# 25  neg        neg             fico         simple_1D      logreg     2347
# 26  neg        pos             fico         simple_1D      logreg      769
# 27  pos        neg             fico         simple_1D      logreg      933
# 28  pos        pos             fico         simple_1D      logreg     1793
# 29  neg        neg             fico         simple_1D      rf         2553
# 30  neg        pos             fico         simple_1D      rf          563
# ⋮   ⋮          ⋮               ⋮            ⋮              ⋮          ⋮
# 79  pos        neg             givemecredit complex_1D     rf            803
# 80  pos        pos             givemecredit complex_1D     rf         111108
# 81  neg        neg             givemecredit complex_1D     xgb          1535
# 82  neg        pos             givemecredit complex_1D     xgb          6822
# 83  pos        neg             givemecredit complex_1D     xgb          1342
# 84  pos        pos             givemecredit complex_1D     xgb        110569
# 85  neg        neg             givemecredit complex_nD     logreg       1536
# 86  neg        pos             givemecredit complex_nD     logreg       6821
# 87  pos        neg             givemecredit complex_nD     logreg       1344
# 88  pos        pos             givemecredit complex_nD     logreg     110567
# 89  neg        neg             givemecredit complex_nD     rf           1267
# 90  neg        pos             givemecredit complex_nD     rf           7090
# 91  pos        neg             givemecredit complex_nD     rf            803
# 92  pos        pos             givemecredit complex_nD     rf         111108
# 93  neg        neg             givemecredit complex_nD     xgb          1535
# 94  neg        pos             givemecredit complex_nD     xgb          6822
# 95  pos        neg             givemecredit complex_nD     xgb          1342
# 96  pos        pos             givemecredit complex_nD     xgb        110569
# 97  neg        neg             givemecredit simple_1D      logreg       1536
# 98  neg        pos             givemecredit simple_1D      logreg       6821
# 99  pos        neg             givemecredit simple_1D      logreg       1344
# 100 pos        pos             givemecredit simple_1D      logreg     110567
# 101 neg        neg             givemecredit simple_1D      rf           1267
# 102 neg        pos             givemecredit simple_1D      rf           7090
# 103 pos        neg             givemecredit simple_1D      rf            803
# 104 pos        pos             givemecredit simple_1D      rf         111108
# 105 neg        neg             givemecredit simple_1D      xgb          1535
# 106 neg        pos             givemecredit simple_1D      xgb          6822
# 107 pos        neg             givemecredit simple_1D      xgb          1342
# 108 pos        pos             givemecredit simple_1D      xgb        110569

# %%
#### build table of recourse stats ####
recourse_cnt_df = raw_df %>%
    filter(actionset_name %in% all_actionset_names,
           model_type %in% all_model_types,
           # grepl("recourse_", stat_name))
           stat_name %in% cell_metric_names
    )

# add normalized metrics
recourse_pct_df = recourse_cnt_df %>%
    left_join(samples_df) %>%
    mutate(stat_value = stat_value / n,
           stat_name = str_replace(stat_name, "_cnt", "_pct")) %>%
    select(-n)

recourse_df = bind_rows(recourse_cnt_df, recourse_pct_df) %>%
    select(data_name, actionset_name, model_type, method_name, everything())

recourse_df
# Out:
# Joining with `by = join_by(label_type, prediction_type, data_name, actionset_name, model_type)`
#      data_name actionset_name model_type method_name
# 1    fico      complex_nD     rf         reach
# 2    fico      complex_nD     rf         reach
# 3    fico      complex_nD     rf         reach
# 4    fico      complex_nD     rf         reach
# 5    fico      complex_nD     rf         reach
# 6    fico      complex_nD     rf         reach
# 7    fico      complex_nD     rf         reach
# 8    fico      complex_nD     rf         reach
# 9    fico      complex_nD     rf         reach
# 10   fico      complex_nD     rf         reach
# 11   fico      complex_nD     rf         reach
# 12   fico      complex_nD     rf         reach
# 13   fico      complex_nD     rf         reach
# 14   fico      complex_nD     rf         reach
# 15   fico      complex_nD     rf         reach
# 16   fico      complex_nD     rf         reach
# 17   fico      complex_nD     rf         reach
# 18   fico      complex_nD     rf         reach
# 19   fico      complex_nD     rf         reach
# 20   fico      complex_nD     rf         reach
# 21   fico      complex_nD     rf         reach
# 22   fico      complex_nD     rf         reach
# 23   fico      complex_nD     rf         reach
# 24   fico      complex_nD     rf         reach
# 25   fico      complex_nD     rf         reach
# 26   fico      complex_nD     rf         reach
# 27   fico      complex_nD     rf         reach
# 28   fico      complex_nD     rf         reach
# 29   fico      complex_nD     rf         reach
# 30   fico      complex_nD     rf         reach
# ⋮    ⋮         ⋮              ⋮          ⋮
# 6019 german    complex_nD     rf         reach
# 6020 german    complex_nD     rf         reach
# 6021 german    complex_nD     rf         reach
# 6022 german    complex_nD     rf         reach
# 6023 german    complex_nD     rf         reach
# 6024 german    complex_nD     rf         reach
# 6025 german    complex_nD     rf         reach
# 6026 german    complex_nD     rf         reach
# 6027 german    complex_nD     rf         reach
# 6028 german    complex_nD     rf         reach
# 6029 german    complex_nD     rf         reach
# 6030 german    complex_nD     rf         reach
# 6031 german    complex_nD     rf         reach
# 6032 german    complex_nD     rf         reach
# 6033 german    complex_nD     rf         reach
# 6034 german    complex_nD     rf         reach
# 6035 german    complex_nD     rf         reach
# 6036 german    complex_nD     rf         reach
# 6037 german    complex_nD     rf         reach
# 6038 german    complex_nD     rf         reach
# 6039 german    complex_nD     rf         reach
# 6040 german    complex_nD     rf         reach
# 6041 german    complex_nD     rf         reach
# 6042 german    complex_nD     rf         reach
# 6043 german    complex_nD     rf         reach
# 6044 german    complex_nD     rf         reach
# 6045 german    complex_nD     rf         reach
# 6046 german    complex_nD     rf         reach
# 6047 german    complex_nD     rf         reach
# 6048 german    complex_nD     rf         reach
#      stat_name                   stat_value label_type prediction_type
# 1    finds_action_cnt            1871       pos        pos
# 2    finds_no_action_cnt            0       pos        pos
# 3    certifies_infeasibility_cnt    0       pos        pos
# 4    abstains_cnt                   0       pos        pos
# 5    loophole_cnt                   0       pos        pos
# 6    blindspot_cnt                  0       pos        pos
# 7    finds_action_cnt             658       pos        neg
# 8    finds_no_action_cnt          197       pos        neg
# 9    certifies_infeasibility_cnt  197       pos        neg
# 10   abstains_cnt                   0       pos        neg
# 11   loophole_cnt                   0       pos        neg
# 12   blindspot_cnt                  0       pos        neg
# 13   finds_action_cnt            2529       pos        all
# 14   finds_no_action_cnt          197       pos        all
# 15   certifies_infeasibility_cnt  197       pos        all
# 16   abstains_cnt                   0       pos        all
# 17   loophole_cnt                   0       pos        all
# 18   blindspot_cnt                  0       pos        all
# 19   finds_action_cnt             563       neg        pos
# 20   finds_no_action_cnt            0       neg        pos
# 21   certifies_infeasibility_cnt    0       neg        pos
# 22   abstains_cnt                   0       neg        pos
# 23   loophole_cnt                   0       neg        pos
# 24   blindspot_cnt                  0       neg        pos
# 25   finds_action_cnt            1682       neg        neg
# 26   finds_no_action_cnt          871       neg        neg
# 27   certifies_infeasibility_cnt  871       neg        neg
# 28   abstains_cnt                   0       neg        neg
# 29   loophole_cnt                   0       neg        neg
# 30   blindspot_cnt                  0       neg        neg
# ⋮    ⋮                           ⋮          ⋮          ⋮
# 6019 finds_action_pct            1.000000   neg        pos
# 6020 finds_no_action_pct         0.000000   neg        pos
# 6021 certifies_infeasibility_pct 0.000000   neg        pos
# 6022 abstains_pct                0.000000   neg        pos
# 6023 loophole_pct                0.000000   neg        pos
# 6024 blindspot_pct               0.000000   neg        pos
# 6025 finds_action_pct            0.702381   neg        neg
# 6026 finds_no_action_pct         0.297619   neg        neg
# 6027 certifies_infeasibility_pct 0.297619   neg        neg
# 6028 abstains_pct                0.000000   neg        neg
# 6029 loophole_pct                0.000000   neg        neg
# 6030 blindspot_pct               0.000000   neg        neg
# 6031 finds_action_pct                  NA   neg        all
# 6032 finds_no_action_pct               NA   neg        all
# 6033 certifies_infeasibility_pct       NA   neg        all
# 6034 abstains_pct                      NA   neg        all
# 6035 loophole_pct                      NA   neg        all
# 6036 blindspot_pct                     NA   neg        all
# 6037 finds_action_pct                  NA   all        pos
# 6038 finds_no_action_pct               NA   all        pos
# 6039 certifies_infeasibility_pct       NA   all        pos
# 6040 abstains_pct                      NA   all        pos
# 6041 loophole_pct                      NA   all        pos
# 6042 blindspot_pct                     NA   all        pos
# 6043 finds_action_pct                  NA   all        neg
# 6044 finds_no_action_pct               NA   all        neg
# 6045 certifies_infeasibility_pct       NA   all        neg
# 6046 abstains_pct                      NA   all        neg
# 6047 loophole_pct                      NA   all        neg
# 6048 blindspot_pct                     NA   all        neg

# %%
#### create table stats
table_stats_df = recourse_df %>%
    filter(prediction_type == "neg", label_type == "neg", endsWith(stat_name, "pct")) %>%
    mutate(svalue = sprintf("%1.0f", stat_value),
           svalue_pct = sprintf("%1.1f\\%%", 100 * stat_value),
           svalue_dec = sprintf("%1.3f", stat_value)) %>%
    mutate(svalue = ifelse(str_detect(stat_name, "_pct"), svalue_pct, svalue),
           svalue = ifelse(is.na(stat_value), EMPTY_TEX_STRING, svalue)) %>%
    mutate(svalue = ifelse(method_name != "reach" & stat_name == "certifies_infeasibility_pct",
                           EMPTY_TEX_STRING, svalue)) %>%
    select(-svalue_pct, -svalue_dec)

table_stats_df
# Out:
#     data_name    actionset_name model_type method_name
# 1   fico         complex_nD     rf         reach
# 2   fico         complex_nD     rf         reach
# 3   fico         complex_nD     rf         reach
# 4   fico         complex_nD     rf         reach
# 5   fico         complex_nD     rf         reach
# 6   fico         complex_nD     rf         reach
# 7   givemecredit complex_nD     logreg     dice
# 8   givemecredit complex_nD     logreg     dice
# 9   givemecredit complex_nD     logreg     dice
# 10  givemecredit complex_nD     logreg     dice
# 11  givemecredit complex_nD     logreg     dice
# 12  givemecredit complex_nD     logreg     dice
# 13  german       complex_1D     xgb        dice
# 14  german       complex_1D     xgb        dice
# 15  german       complex_1D     xgb        dice
# 16  german       complex_1D     xgb        dice
# 17  german       complex_1D     xgb        dice
# 18  german       complex_1D     xgb        dice
# 19  fico         simple_1D      logreg     ar
# 20  fico         simple_1D      logreg     ar
# 21  fico         simple_1D      logreg     ar
# 22  fico         simple_1D      logreg     ar
# 23  fico         simple_1D      logreg     ar
# 24  fico         simple_1D      logreg     ar
# 25  givemecredit simple_1D      rf         reach
# 26  givemecredit simple_1D      rf         reach
# 27  givemecredit simple_1D      rf         reach
# 28  givemecredit simple_1D      rf         reach
# 29  givemecredit simple_1D      rf         reach
# 30  givemecredit simple_1D      rf         reach
# ⋮   ⋮            ⋮              ⋮          ⋮
# 349 german       complex_1D     logreg     reach
# 350 german       complex_1D     logreg     reach
# 351 german       complex_1D     logreg     reach
# 352 german       complex_1D     logreg     reach
# 353 german       complex_1D     logreg     reach
# 354 german       complex_1D     logreg     reach
# 355 givemecredit simple_1D      xgb        reach
# 356 givemecredit simple_1D      xgb        reach
# 357 givemecredit simple_1D      xgb        reach
# 358 givemecredit simple_1D      xgb        reach
# 359 givemecredit simple_1D      xgb        reach
# 360 givemecredit simple_1D      xgb        reach
# 361 german       complex_nD     rf         dice
# 362 german       complex_nD     rf         dice
# 363 german       complex_nD     rf         dice
# 364 german       complex_nD     rf         dice
# 365 german       complex_nD     rf         dice
# 366 german       complex_nD     rf         dice
# 367 fico         simple_1D      rf         dice
# 368 fico         simple_1D      rf         dice
# 369 fico         simple_1D      rf         dice
# 370 fico         simple_1D      rf         dice
# 371 fico         simple_1D      rf         dice
# 372 fico         simple_1D      rf         dice
# 373 german       complex_nD     rf         reach
# 374 german       complex_nD     rf         reach
# 375 german       complex_nD     rf         reach
# 376 german       complex_nD     rf         reach
# 377 german       complex_nD     rf         reach
# 378 german       complex_nD     rf         reach
#     stat_name                   stat_value   label_type prediction_type
# 1   finds_action_pct            0.6588327458 neg        neg
# 2   finds_no_action_pct         0.3411672542 neg        neg
# 3   certifies_infeasibility_pct 0.3411672542 neg        neg
# 4   abstains_pct                0.0000000000 neg        neg
# 5   loophole_pct                0.0000000000 neg        neg
# 6   blindspot_pct               0.0000000000 neg        neg
# 7   finds_action_pct            1.0000000000 neg        neg
# 8   finds_no_action_pct         0.0000000000 neg        neg
# 9   certifies_infeasibility_pct 0.0000000000 neg        neg
# 10  abstains_pct                0.0000000000 neg        neg
# 11  loophole_pct                0.8580729167 neg        neg
# 12  blindspot_pct               0.0000000000 neg        neg
# 13  finds_action_pct            0.9144736842 neg        neg
# 14  finds_no_action_pct         0.0855263158 neg        neg
# 15  certifies_infeasibility_pct 0.0000000000 neg        neg
# 16  abstains_pct                0.0000000000 neg        neg
# 17  loophole_pct                0.1842105263 neg        neg
# 18  blindspot_pct               0.0000000000 neg        neg
# 19  finds_action_pct            0.9991478483 neg        neg
# 20  finds_no_action_pct         0.0008521517 neg        neg
# 21  certifies_infeasibility_pct 0.0008521517 neg        neg
# 22  abstains_pct                0.0000000000 neg        neg
# 23  loophole_pct                0.9599488709 neg        neg
# 24  blindspot_pct               0.0000000000 neg        neg
# 25  finds_action_pct            1.0000000000 neg        neg
# 26  finds_no_action_pct         0.0000000000 neg        neg
# 27  certifies_infeasibility_pct 0.0000000000 neg        neg
# 28  abstains_pct                0.0000000000 neg        neg
# 29  loophole_pct                0.0000000000 neg        neg
# 30  blindspot_pct               0.0000000000 neg        neg
# ⋮   ⋮                           ⋮            ⋮          ⋮
# 349 finds_action_pct            0.91503268   neg        neg
# 350 finds_no_action_pct         0.08496732   neg        neg
# 351 certifies_infeasibility_pct 0.08496732   neg        neg
# 352 abstains_pct                0.00000000   neg        neg
# 353 loophole_pct                0.00000000   neg        neg
# 354 blindspot_pct               0.00000000   neg        neg
# 355 finds_action_pct            1.00000000   neg        neg
# 356 finds_no_action_pct         0.00000000   neg        neg
# 357 certifies_infeasibility_pct 0.00000000   neg        neg
# 358 abstains_pct                0.00000000   neg        neg
# 359 loophole_pct                0.00000000   neg        neg
# 360 blindspot_pct               0.00000000   neg        neg
# 361 finds_action_pct            0.66666667   neg        neg
# 362 finds_no_action_pct         0.33333333   neg        neg
# 363 certifies_infeasibility_pct 0.00000000   neg        neg
# 364 abstains_pct                0.00000000   neg        neg
# 365 loophole_pct                0.24404762   neg        neg
# 366 blindspot_pct               0.03571429   neg        neg
# 367 finds_action_pct            0.55229142   neg        neg
# 368 finds_no_action_pct         0.44770858   neg        neg
# 369 certifies_infeasibility_pct 0.00000000   neg        neg
# 370 abstains_pct                0.00000000   neg        neg
# 371 loophole_pct                0.41754798   neg        neg
# 372 blindspot_pct               0.16647082   neg        neg
# 373 finds_action_pct            0.70238095   neg        neg
# 374 finds_no_action_pct         0.29761905   neg        neg
# 375 certifies_infeasibility_pct 0.29761905   neg        neg
# 376 abstains_pct                0.00000000   neg        neg
# 377 loophole_pct                0.00000000   neg        neg
# 378 blindspot_pct               0.00000000   neg        neg
#     svalue
# 1   65.9\\%
# 2   34.1\\%
# 3   34.1\\%
# 4   0.0\\%
# 5   0.0\\%
# 6   0.0\\%
# 7   100.0\\%
# 8   0.0\\%
# 9   ---
# 10  0.0\\%
# 11  85.8\\%
# 12  0.0\\%
# 13  91.4\\%
# 14  8.6\\%
# 15  ---
# 16  0.0\\%
# 17  18.4\\%
# 18  0.0\\%
# 19  99.9\\%
# 20  0.1\\%
# 21  ---
# 22  0.0\\%
# 23  96.0\\%
# 24  0.0\\%
# 25  100.0\\%
# 26  0.0\\%
# 27  0.0\\%
# 28  0.0\\%
# 29  0.0\\%
# 30  0.0\\%
# ⋮   ⋮
# 349 91.5\\%
# 350 8.5\\%
# 351 8.5\\%
# 352 0.0\\%
# 353 0.0\\%
# 354 0.0\\%
# 355 100.0\\%
# 356 0.0\\%
# 357 0.0\\%
# 358 0.0\\%
# 359 0.0\\%
# 360 0.0\\%
# 361 66.7\\%
# 362 33.3\\%
# 363 ---
# 364 0.0\\%
# 365 24.4\\%
# 366 3.6\\%
# 367 55.2\\%
# 368 44.8\\%
# 369 ---
# 370 0.0\\%
# 371 41.8\\%
# 372 16.6\\%
# 373 70.2\\%
# 374 29.8\\%
# 375 29.8\\%
# 376 0.0\\%
# 377 0.0\\%
# 378 0.0\\%

# %%
cells_df = table_stats_df %>%
    # filter(model_type %in% c("finds_action_pct", "finds_no_action_pct", "certifies_pct", "loophole_pct", "blindspot_pct")) %>%
    arrange(data_name, actionset_name, model_type, method_name) %>%
    select(-stat_value, -label_type, -prediction_type) %>%
    pivot_wider(
        names_from = stat_name,
        values_from = svalue
    )

head(cells_df)
# Out:
#   data_name actionset_name model_type method_name finds_action_pct
# 1 fico      complex_1D     logreg     ar          83.3\\%
# 2 fico      complex_1D     logreg     dice        51.6\\%
# 3 fico      complex_1D     logreg     reach       74.2\\%
# 4 fico      complex_1D     rf         dice        45.9\\%
# 5 fico      complex_1D     rf         reach       65.9\\%
# 6 fico      complex_1D     xgb        dice        52.4\\%
#   finds_no_action_pct certifies_infeasibility_pct abstains_pct loophole_pct
# 1 16.7\\%             ---                         0.0\\%       41.5\\%
# 2 48.4\\%             ---                         0.0\\%       32.3\\%
# 3 25.8\\%             25.8\\%                     0.0\\%       0.0\\%
# 4 54.1\\%             ---                         0.0\\%       26.8\\%
# 5 34.1\\%             34.1\\%                     0.0\\%       0.0\\%
# 6 47.6\\%             ---                         0.0\\%       38.6\\%
#   blindspot_pct
# 1 0.0\\%
# 2 23.5\\%
# 3 0.0\\%
# 4 20.3\\%
# 5 0.0\\%
# 6 22.7\\%

# %%
table_df = cells_df %>%
    filter(actionset_name == "complex_nD") %>%
    # Add bolds and colors
    mutate(loophole_pct = ifelse(
        method_name == "reach",
        sprintf("\\textbf{%s}", loophole_pct),
        loophole_pct)
    ) %>%
    mutate(loophole_pct = ifelse(
        method_name != "reach" & loophole_pct != "0.0\\%",
        sprintf("\\textcolor{\\pitfall}{%s}", loophole_pct),
        loophole_pct)
    ) %>%
    mutate(blindspot_pct = ifelse(
        method_name == "reach",
        sprintf("\\textbf{%s}", blindspot_pct),
        blindspot_pct)
    ) %>%
    mutate(blindspot_pct = ifelse(
        method_name != "reach" & blindspot_pct != "0.0\\%",
        sprintf("\\textcolor{\\pitfall}{%s}", blindspot_pct),
        blindspot_pct)
    ) %>%
    group_by(data_name, actionset_name, model_type, method_name) %>%
    unite(cell_str, sep = "\\\\", all_of(str_replace(cell_metric_names, "_cnt", "_pct"))) %>%
    mutate(cell_str = sprintf("\\cell{r}{%s}\n", cell_str)) %>%
    ungroup() %>%
    select(!actionset_name) %>%
    arrange(data_name,
            match(model_type, all_model_types),
            match(method_name, all_method_names)
    )

# create headers manually to avoid unique names issues
headers_df = table_df %>%
    mutate(model_type = model_type, method_name = str_to_lower(method_name)) %>%
    group_by(model_type) %>%
    distinct(method_name)

# top level columns (model type)
top_headers = headers_df %>%
    group_by(model_type) %>%
    count() %>%
    arrange(match(model_type, all_model_types)) %>%
    mutate(model_type = recode(model_type, !!!MODEL_TYPE_TITLES)) %>%
    pull(name = model_type) %>%
    prepend(c(" " = 2))

# bottom level columns (methods)
sub_headers = headers_df %>%
    mutate(method_name = str_to_lower(method_name)) %>%
    pull(method_name) %>%
    prepend(c("Dataset", "Metrics")) %>%
    recode(!!!METHOD_TITLES)

kable_df = table_df %>%
  mutate(
    metrics = "\\metricsguide{}",
    data_name = recode(data_name, !!!DATASET_TITLES)
  ) %>%
  pivot_wider(
    names_from = c(model_type, method_name),
    values_from = cell_str,
    names_sort = FALSE,
    names_glue = "{model_type}+{method_name}",
  )

overview_table = kable_df %>%
    kable(
        booktabs = TRUE,
        escape = FALSE,
        col.names = sub_headers,
        format = "latex",
        table.envir = NULL,
        linesep = ""
    ) %>%
    #kable_styling(latex_options = c("repeat_header", "scale_down", latex_table_env = NULL)) %>%
    add_header_above(top_headers, bold = FALSE, escape = FALSE) %>%
    column_spec(column = 1, latex_column_spec = "r") %>%
    column_spec(column = 2, latex_column_spec = "r") %>%
    column_spec(column = 3, latex_column_spec = "r") %>%
    column_spec(column = 4, latex_column_spec = "r") %>%
    row_spec(2:nrow(kable_df)-1, hline_after = TRUE, extra_latex_after = "\n")

overview_table
# Out:
# Warning message:
# “`prepend()` was deprecated in purrr 1.0.0.
# ℹ Please use append(after = 0) instead.”
# \begin{tabular}{rrrrlllll}
# \toprule
# \multicolumn{2}{c}{ } & \multicolumn{3}{c}{LR{}} & \multicolumn{2}{c}{XGB{}} & \multicolumn{2}{c}{RF{}} \\
# \cmidrule(l{3pt}r{3pt}){3-5} \cmidrule(l{3pt}r{3pt}){6-7} \cmidrule(l{3pt}r{3pt}){8-9}
# Dataset & Metrics & \reach{} & \ar{} & \dice{} & \reach{} & \dice{} & \reach{} & \dice{}\\
    unite(cell_str, sep = "\\\\", all_of(str_replace(cell_metric_names, "_cnt", "_pct"))) %>%
    mutate(cell_str = sprintf("\\cell{r}{%s}\n", cell_str)) %>%
    ungroup() %>%
    arrange(data_name,
            match(actionset_name, all_actionset_names),
            match(model_type, all_model_types))

# create headers manually to avoid unique names issues
headers_df = table_df %>%
    mutate(actionset_name = str_to_lower(actionset_name), method_name = str_to_lower(method_name)) %>%
    arrange(match(model_type, all_model_types),
            match(method_name, all_method_names))

# create headers manually to avoid unique names issues
headers_df = table_df %>%
    mutate(actionset_name = actionset_name, method_name = str_to_lower(method_name)) %>%
    group_by(actionset_name) %>%
    distinct(method_name)

# top level columns (actionability)
top_headers = headers_df %>%
    group_by(actionset_name) %>%
    count() %>%
    arrange(match(actionset_name, all_actionset_names)) %>%
    mutate(actionset_name = recode(actionset_name, !!!ACTIONSET_TITLES)) %>%
    pull(name = actionset_name) %>%
    prepend(c(" " = 3))

# bottom level columns (methods)
sub_headers = headers_df %>%
    mutate(method_name = str_to_lower(method_name)) %>%
    pull(method_name) %>%
    prepend(c("Dataset", "Model Type", "Metrics")) %>%
    recode(!!!METHOD_TITLES)

kable_df = table_df %>%
    mutate(
           metrics = "\\metricsguide{}",
           model_type = recode(model_type, !!!MODEL_TYPE_TITLES),
           data_name = recode(data_name, !!!DATASET_TITLES)
           ) %>%
    pivot_wider(
        names_from = c(actionset_name, method_name),
        values_from = cell_str,
        names_sort = FALSE,
        names_glue = "{actionset_name}+{method_name}",
    )

overview_table = kable_df %>%
    kable(
        booktabs = TRUE,
        escape = FALSE,
        col.names = sub_headers,
        format = "latex",
        table.envir = NULL,
        linesep = ""
    ) %>%
    #kable_styling(latex_options = c("repeat_header", "scale_down", latex_table_env = NULL)) %>%
    add_header_above(top_headers, bold = FALSE, escape = FALSE) %>%
    column_spec(column = 1, latex_column_spec = "r") %>%
    column_spec(column = 2, latex_column_spec = "r") %>%
    column_spec(column = 3, latex_column_spec = "r") %>%
    row_spec(2:nrow(kable_df)-1, hline_after = TRUE, extra_latex_after = "\n")

overview_table
# Out:
# \begin{tabular}{rrrlllllllll}
# \toprule
# \multicolumn{3}{c}{ } & \multicolumn{3}{c}{Simple} & \multicolumn{3}{c}{Separable} & \multicolumn{3}{c}{Actual} \\
# \cmidrule(l{3pt}r{3pt}){4-6} \cmidrule(l{3pt}r{3pt}){7-9} \cmidrule(l{3pt}r{3pt}){10-12}
# Dataset & Model Type & Metrics & \ar{} & \dice{} & \reach{} & \ar{} & \dice{} & \reach{} & \ar{} & \dice{} & \reach{}\\
# \midrule
# \ficoinfo{} & \LR{} & \metricsguide{} & \cell{r}{---\\0.0\%\\99.9\%\\96.0\%\\0.1\%\\0.0\%} & \cell{r}{---\\0.0\%\\59.9\%\\45.9\%\\40.1\%\\16.7\%} & \cell{r}{25.8\%\\0.0\%\\74.2\%\\0.0\%\\25.8\%\\0.0\%} & \cell{r}{---\\0.0\%\\83.3\%\\41.5\%\\16.7\%\\0.0\%} & \cell{r}{---
# \bottomrule
# \end{tabular}

# %%
# print metric titles
cell_metric_titles = METRIC_TITLES[cell_metric_names]
metrics_cmd = paste0("\\renewcommand{\\metricsguide}[0]{\\cell{r}{",paste0(cell_metric_titles, collapse = "\\\\"), "}}")
metrics_cmd
# Out:
# [1] "\\renewcommand{\\metricsguide}[0]{\\cell{r}{Certifies no recourse\\\\Abstains/inconclusive\\\\Finds action\\\\Loophole\\\\Finds no action\\\\Blindspot}}"

# %%
model_data <- read_csv("../results/model_stats.csv", show_col_types = FALSE)

model_data %>%
    filter(action_set_name == "complex_nD") %>%
    select(c("data_name", "model_type", "train_auc", "test_auc", "train_error", "test_error")) %>%
    mutate(
        model_type = recode(model_type, !!!MODEL_TYPE_TITLES),
        data_name = sprintf("\\textfn{%s}", data_name)
    ) %>%

    kable(
        booktabs = TRUE,
        escape = FALSE,
        col.names = c("Dataset", "Model", "Train", "Test", "Train", "Test"),
        format = "latex",
        table.envir = NULL,
        linesep = ""
    ) %>%
    # kable_styling(latex_options = c("repeat_header", "scale_down", latex_table_env = NULL))
    add_header_above(c(" " = 2, "AUC" = 2, "Error" = 2), bold = FALSE, escape = FALSE)
    # column_spec(column = 1, latex_column_spec = "r") %>%
    # column_spec(column = 2, latex_column_spec = "r") %>%
    # row_spec(2:nrow(kable_df)-1, hline_after = TRUE, extra_latex_after = "\n")
# Out:
# \begin{tabular}{llrrrr}
# \toprule
# \multicolumn{2}{c}{ } & \multicolumn{2}{c}{AUC} & \multicolumn{2}{c}{Error} \\
# \cmidrule(l{3pt}r{3pt}){3-4} \cmidrule(l{3pt}r{3pt}){5-6}
# Dataset & Model & Train & Test & Train & Test\\
# \midrule
# \textfn{fico} & \LR{} & 0.7723 & 0.7882 & 0.2774 & 0.2774\\
# \textfn{fico} & \XGB{} & 0.7721 & 0.7880 & 0.2783 & 0.2783\\
# \textfn{fico} & \RF{} & 0.8593 & 0.7853 & 0.2877 & 0.2877\\
# \textfn{german} & \LR{} & 0.8193 & 0.7602 & 0.2350 & 0.2350\\
# \textfn{german} & \XGB{} & 0.8191 & 0.7614 & 0.2300 & 0.2300\\
# \textfn{german} & \RF{} & 0.9708 & 0.7937 & 0.2350 & 0.2350\\
# \textfn{givemecredit} & \LR{} & 0.8418 & 0.8437 & 0.0681 & 0.0681\\
# \textfn{givemecredit} & \XGB{} & 0.8418 & 0.8438 & 0.0681 & 0.0681\\
# \textfn{givemecredit} & \RF{} & 0.8626 & 0.8389 & 0.0681 & 0.0681\\
# \bottomrule
# \end{tabular}

# %%
data_stats <- read_csv("../results/data_stats.csv", show_col_types = FALSE) %>%
    filter(action_set_name == "complex_nD")

data_stats
# Out:
#   data_name    action_set_name n      d
# 1 fico         complex_nD        5842 43
# 2 german       complex_nD        1000 36
# 3 givemecredit complex_nD      120268 23
